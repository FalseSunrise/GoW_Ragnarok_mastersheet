# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import lxml
import html5lib
from unidecode import unidecode

# %% [markdown]
# ## Fetching armor sets from godofwar.fandom.com

# %%
def getHtmlText(url): 
    response = requests.get(url) 
    return response.text

# %%
# Create soup
url = 'https://godofwar.fandom.com/wiki/Armor_Sets_(Ragnar%C3%B6k)'
doc = getHtmlText(url)
soup = BeautifulSoup(doc, 'html.parser')

# Create list of sets names with corresponding urls to wiki
armorSetsLinks = []
div = soup.find(class_='mw-parser-output')
uls = div.find_all('ul')[3:11]

for i in uls:
    lis = i.find_all('li')
    for j in lis:
        setName = j.a['title']
        link = 'https://godofwar.fandom.com' + j.a['href']
        armorSetsLinks.append((setName, link))

# %%
armorSetsLinks
# Out:
# [('Survival Set', 'https://godofwar.fandom.com/wiki/Survival_Set'),
#  ('Fortified Husk Set', 'https://godofwar.fandom.com/wiki/Fortified_Husk_Set'),
#  ("Vidar's Set of Might",
#   'https://godofwar.fandom.com/wiki/Vidar%27s_Set_of_Might'),
#  ('Risen Snow Set', 'https://godofwar.fandom.com/wiki/Risen_Snow_Set'),
#  ('Darkdale Set', 'https://godofwar.fandom.com/wiki/Darkdale_Set'),
#  ("Niðavellir's Finest Set",
#   'https://godofwar.fandom.com/wiki/Ni%C3%B0avellir%27s_Finest_Set'),
#  ('Enlightenment Set', 'https://godofwar.fandom.com/wiki/Enlightenment_Set'),
#  ('Raven Tears Set', 'https://godofwar.fandom.com/wiki/Raven_Tears_Set'),
#  ('Radiance Set', 'https://godofwar.fandom.com/wiki/Radiance_Set'),
#  ('Spiritual Set', 'https://godofwar.fandom.com/wiki/Spiritual_Set'),
#  ("Sól's Set of Courage",
#   'https://godofwar.fandom.com/wiki/S%C3%B3l%27s_Set_of_Courage'),
#  ("Lúnda's Lost Set",
#   'https://godofwar.fandom.com/wiki/L%C3%BAnda%27s_Lost_Set'),
#  ('Guiding Light Set', 'https://godofwar.fandom.com/wiki/Guiding_Light_Set'),
#  ("Giptumaðr's Set",
#   'https://godofwar.fandom.com/wiki/Giptuma%C3%B0r%27s_Set'),
#  ("Máni's Set of Wisdom",
#   'https://godofwar.fandom.com/wiki/M%C3%A1ni%27s_Set_of_Wisdom'),
#  ('Berserker Set', 'https://godofwar.fandom.com/wiki/Berserker_Set'),
#  ('Steinbjörn Set', 'https://godofwar.fandom.com/wiki/Steinbj%C3%B6rn_Set'),
#  ('Fallen Stars Set', 'https://godofwar.fandom.com/wiki/Fallen_Stars_Set'),
#  ('Dragon Scaled Set', 'https://godofwar.fandom.com/wiki/Dragon_Scaled_Set'),
#  ('Undying Pyres Set', 'https://godofwar.fandom.com/wiki/Undying_Pyres_Set'),
#  ("Hunter's Set", 'https://godofwar.fandom.com/wiki/Hunter%27s_Set'),
#  ('Fate Breaker Set', 'https://godofwar.fandom.com/wiki/Fate_Breaker_Set'),
#  ("Surtr's Scorched Set",
#   'https://godofwar.fandom.com/wiki/Surtr%27s_Scorched_Set'),
#  ('Black Bear Set', 'https://godofwar.fandom.com/wiki/Black_Bear_Set'),
#  ('Spartan Set', 'https://godofwar.fandom.com/wiki/Spartan_Set'),
#  ('Spartan Set (Valhalla)',
#   'https://godofwar.fandom.com/wiki/Spartan_Set_(Valhalla)'),
#  ('Armor of Ares (Ragnarök)',
#   'https://godofwar.fandom.com/wiki/Armor_of_Ares_(Ragnar%C3%B6k)'),
#  ('Armor of Zeus (Ragnarök)',
#   'https://godofwar.fandom.com/wiki/Armor_of_Zeus_(Ragnar%C3%B6k)')]

# %%
# Convert item level
def getLevel(col):
    list = col.split(' ')
    if '•' in list[-1]:
        return list[1] + '.' + str(list[-1].count('•'))
    else: return list[1]

# %%
# Get item properties from dataframe, return a part of final dataframe
def getItemFeatures(table, df_main):
    table = table.copy()
    title = table.columns[0][0]
    itemType = ''

    if ': ' in title:
        split = title.split(': ')
        title = split[1]

        if split[0].lower() == 'chest': 
            itemType = 'Chest Armor'
        elif split[0].lower() == 'wrist': 
            itemType = 'Wrist Armor'
        elif split[0].lower() == 'waist': 
            itemType = 'Waist Armor'

    itemName = title.replace(' +', '')

    table.columns = table.columns.droplevel()
    table.rename(columns={'Stats': 'Lvl', 'Level': 'Lvl'}, inplace=True)
    table.rename(columns={'Acquisition': 'Acquisition/Costs'}, inplace=True)

    perk = '-'
    if table.iat[table.shape[0]-1, 0].lower() == 'perk':
        perk = table.at[table.shape[0]-2, 'Acquisition/Costs'] + ': ' + table.at[table.shape[0]-1, 'Acquisition/Costs']
        table = table[:-2]

    correctRows = range(0, table.shape[0], 2)

    for i in correctRows:
        stats = table.at[i+1, 'Lvl'].split(' ')
        for j in range(1, len(stats), 2):
            table.at[i, stats[j]] = stats[j-1]

    table = table.iloc[correctRows]
    
    table[['Item', 'Type']] = [itemName, itemType]
    table['Perk'] = perk
    table['Lvl'] = table['Lvl'].apply(getLevel)

    return table

# %%
# Fetch item information tables from corresponding urls
dfArmor = pd.DataFrame()

for i in armorSetsLinks:
    print(i[0])
    tables = pd.read_html(i[1])

    for j in range(2,min(8, len(tables))):
        try:
            newTable = getItemFeatures(tables[j], dfArmor)
        except Exception as error:
            print("An exception occurred:", error)
        else:
            newTable[['Set', 'Wiki Link']] = i[0], i[1]
            i[1]
            dfArmor = pd.concat([dfArmor, newTable], ignore_index=True, axis=0)
# Out:
# Survival Set
# Fortified Husk Set
# Vidar's Set of Might
# Risen Snow Set
# Darkdale Set
# Niðavellir's Finest Set
# Enlightenment Set
# Raven Tears Set
# Radiance Set
# Spiritual Set
# Sól's Set of Courage
# Lúnda's Lost Set
# Guiding Light Set
# Giptumaðr's Set
# Máni's Set of Wisdom
# Berserker Set
# Steinbjörn Set
# Fallen Stars Set
# Dragon Scaled Set
# Undying Pyres Set
# Hunter's Set
# Fate Breaker Set
# Surtr's Scorched Set
# Black Bear Set
# Spartan Set
# Spartan Set (Valhalla)
# Armor of Ares (Ragnarök)
# Armor of Zeus (Ragnarök)

# %%
# Add the missing NG+ Spartan set as its wiki page varies from other sets
spartanSet = pd.DataFrame({'Item': ['Sorrow of Sparta', 'Scars of Sparta', 'Woe of Sparta'], 
                           'Set': ['Spartan Set'] * 3,
                           'Type': ['Chest Armor', 'Wrist Armor', 'Waist Armor'],
                           'Lvl': ['1'] * 3,
                           'Acquisition/Costs': ['Costs 25,000 Hacksilver', 'Costs 16,500 Hacksilver', 'Costs 16,500 Hacksilver'],
                           'Perk': ['-'] * 3,
                           'Wiki Link': ['https://godofwar.fandom.com/wiki/Spartan_Set'] * 3})
dfArmor = pd.concat([dfArmor, spartanSet], ignore_index=True, axis=0)

# %%
# Format the dataframe with all armor parts
dfArmor = dfArmor[['Item', 'Set', 'Type', 'Lvl','STR', 'DEF', 'RNC', 'VIT', 'CLD', 'LCK', 'Acquisition/Costs', 'Wiki Link', 'Perk']]
dfArmor = dfArmor.astype({'STR': 'float', 'DEF': 'float', 'RNC': 'float', 'VIT': 'float', 'CLD': 'float', 'LCK': 'float'})
dfArmor.dtypes
# Out:
# Item                  object
# Set                   object
# Type                  object
# Lvl                   object
# STR                  float64
# DEF                  float64
# RNC                  float64
# VIT                  float64
# CLD                  float64
# LCK                  float64
# Acquisition/Costs     object
# Wiki Link             object
# Perk                  object
# dtype: object

# %%
# Dataframe with armor parts
dfArmor
# Out:
#                            Item                       Set         Type Lvl  \
# 0    Shoulder Guard of Survival              Survival Set  Chest Armor   1
# 1    Shoulder Guard of Survival              Survival Set  Chest Armor   2
# 2    Shoulder Guard of Survival              Survival Set  Chest Armor   3
# 3    Shoulder Guard of Survival              Survival Set  Chest Armor   4
# 4    Shoulder Guard of Survival              Survival Set  Chest Armor   5
# ..                          ...                       ...          ...  ..
# 750          Gauntlets of Zeus+  Armor of Zeus (Ragnarök)               10
# 751           War Belt of Zeus+  Armor of Zeus (Ragnarök)               10
# 752            Sorrow of Sparta               Spartan Set  Chest Armor   1
# 753             Scars of Sparta               Spartan Set  Wrist Armor   1
# 754               Woe of Sparta               Spartan Set  Waist Armor   1
#
#        STR    DEF   RNC  VIT  CLD  LCK  \
# 0      NaN    2.0   NaN  NaN  NaN  NaN
# 1     12.0   12.0   NaN  NaN  NaN  NaN
# 2     20.0   20.0   NaN  NaN  NaN  NaN
# 3     28.0   28.0   NaN  NaN  NaN  NaN
# 4     36.0   36.0   NaN  NaN  NaN  NaN
# ..     ...    ...   ...  ...  ...  ...
# 750  125.0    NaN  50.0  NaN  NaN  NaN
# 751    NaN  125.0  50.0  NaN  NaN  NaN
# 752    NaN    NaN   NaN  NaN  NaN  NaN
# 753    NaN    NaN   NaN  NaN  NaN  NaN
# 754    NaN    NaN   NaN  NaN  NaN  NaN
#
#                                      Acquisition/Costs  \
# 0                                        Default armor
# 1          Upgrade: - 1,000 Hacksilver - 5 Forged Iron
# 2         Upgrade: - 2,000 Hacksilver - 10 Forged Iron
# 3        Upgrade: - 6,000 Hacksilver - 4 Dwarven Steel
# 4       Upgrade: - 10,000 Hacksilver - 8 Dwarven Steel
# ..                                                 ...
# 750  Favor: Remnants of Asgard - The Barrens, Alfhe...
# 751  Favor: Remnants of Asgard - Eastern Barri Wood...
# 752                            Costs 25,000 Hacksilver
# 753                            Costs 16,500 Hacksilver
# 754                            Costs 16,500 Hacksilver
#
#                                              Wiki Link  \
# 0        https://godofwar.fandom.com/wiki/Survival_Set
# 1        https://godofwar.fandom.com/wiki/Survival_Set
# 2        https://godofwar.fandom.com/wiki/Survival_Set
# 3        https://godofwar.fandom.com/wiki/Survival_Set
# 4        https://godofwar.fandom.com/wiki/Survival_Set
# ..                                                 ...
# 750  https://godofwar.fandom.com/wiki/Armor_of_Zeus...
# 751  https://godofwar.fandom.com/wiki/Armor_of_Zeus...
# 752       https://godofwar.fandom.com/wiki/Spartan_Set
# 753       https://godofwar.fandom.com/wiki/Spartan_Set
# 754       https://godofwar.fandom.com/wiki/Spartan_Set
#
#                                                   Perk
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 750  Divine Edge: Increases Kratos' Melee and Runic...
# 751  Divine Edge: Increases Kratos' Melee and Runic...
# 752                                                  -
# 753                                                  -
# 754                                                  -
#
# [755 rows x 13 columns]

# %% [markdown]
# ## Fetching weapon attachments from godofwar.fandom.com and game8.co

# %%
# Fetch attachments links from wiki
url = 'https://godofwar.fandom.com/wiki/Attachments_(Ragnar%C3%B6k)'
doc = getHtmlText(url)
soup = BeautifulSoup(doc, 'html.parser')

# Create a dictionary with names of attachments with corresponding urls
weapons = ['Axe', 'Blades', 'Spear', 'Shield']
div = soup.find(class_='mw-parser-output')
uls = div.findAll('ul')[2:6]

linkDict = {'Axe': pd.Series(), 
                'Blades': pd.Series(), 
                'Spear': pd.Series(), 
                'Shield': pd.Series()}

for i in zip(weapons, uls):
    lis = i[1].find_all('li')
    for j in lis:
        link = 'https://godofwar.fandom.com' + j.a['href']
        #attachmentsLinks.append((i[0], j.a.text, link))
        linkDict[i[0]].at[j.a.text] = link

linkDict
# Out:
# {'Axe': Wooden Knob                          https://godofwar.fandom.com/wiki/Wooden_Knob
#  The Furious Maul                https://godofwar.fandom.com/wiki/The_Furious_Maul
#  Grip of Darkdale                https://godofwar.fandom.com/wiki/Grip_of_Darkdale
#  Fortified Frost Knob            https://godofwar.fandom.com/wiki/Fortified_Fro...
#  Haur's Lucky Knob               https://godofwar.fandom.com/wiki/Haur%27s_Luck...
#  Grip of Weighted Recovery       https://godofwar.fandom.com/wiki/Grip_of_Weigh...
#  Stonecutter's Knob              https://godofwar.fandom.com/wiki/Stonecutter%2...
#  Grip of Healing Harmony         https://godofwar.fandom.com/wiki/Grip_of_Heali...
#  Grip of the Fallen Alchemist    https://godofwar.fandom.com/wiki/Grip_of_the_F...
#  Grip of Radiant Reflection      https://godofwar.fandom.com/wiki/Grip_of_Radia...
#  Banahogg Knob                      https://godofwar.fandom.com/wiki/Banahogg_Knob
#  Runic Hailstone Knob            https://godofwar.fandom.com/wiki/Runic_Hailsto...
#  Grip of the Nine Realms         https://godofwar.fandom.com/wiki/Grip_of_the_N...
#  dtype: object,
#  'Blades': Steel Handles                      https://godofwar.fandom.com/wiki/Steel_Handles
#  Deadly Obsidian Handles         https://godofwar.fandom.com/wiki/Deadly_Obsidi...
#  Darkdale Handles                https://godofwar.fandom.com/wiki/Darkdale_Handles
#  Cursed Empress Handles          https://godofwar.fandom.com/wiki/Cursed_Empres...
#  Pommels of the Undying Spark    https://godofwar.fandom.com/wiki/Pommels_of_th...
#  Radiant Warden Handles          https://godofwar.fandom.com/wiki/Radiant_Warde...
#  Pommels of Agile Deceit         https://godofwar.fandom.com/wiki/Pommels_of_Ag...
#  Pommels of Brutal Might         https://godofwar.fandom.com/wiki/Pommels_of_Br...
#  Hardened War Handles            https://godofwar.fandom.com/wiki/Hardened_War_...
#  Pommels of the True Flame       https://godofwar.fandom.com/wiki/Pommels_of_th...
#  Pommels of the Nine Realms      https://godofwar.fandom.com/wiki/Pommels_of_th...
#  Pommels of Burning Unity        https://godofwar.fandom.com/wiki/Pommels_of_Bu...
#  Luminous Recovery Handles       https://godofwar.fandom.com/wiki/Luminous_Reco...
#  dtype: object,
#  'Spear': Soldier's Sauroter             https://godofwar.fandom.com/wiki/Soldier%27s_S...
#  Lion's Roar Sauroter           https://godofwar.fandom.com/wiki/Lion%27s_Roar...
#  Charging Assault Sauroter      https://godofwar.fandom.com/wiki/Charging_Assa...
#  Mighty Olympic Sauroter        https://godofwar.fandom.com/wiki/Mighty_Olympi...
#  Hind of Attuned Elements       https://godofwar.fandom.com/wiki/Hind_of_Attun...
#  Battle-Scarred Sauroter        https://godofwar.fandom.com/wiki/Battle-Scarre...
#  Hind of Weightless Recovery    https://godofwar.fandom.com/wiki/Hind_of_Weigh...
#  Hind of Volatile Might         https://godofwar.fandom.com/wiki/Hind_of_Volat...
#  Hind of the Nine Realms        https://godofwar.fandom.com/wiki/Hind_of_the_N...
#  Hind of the Four Winds         https://godofwar.fandom.com/wiki/Hind_of_the_F...
#  Warrior's Echo Sauroter        https://godofwar.fandom.com/wiki/Warrior%27s_E...
#  Hind of Deadly Vitality        https://godofwar.fandom.com/wiki/Hind_of_Deadl...
#  dtype: object,
#  'Shield': Rönd of Volition           https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of Aggravation        https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of Expedition         https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of Affliction         https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of Restoration        https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of Deflection         https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of Purification       https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of the Nine Realms    https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of Fortification      https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of Absorption         https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of Disruption         https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  Rönd of Obliteration       https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#  dtype: object}

# %%
# For every attachment get a url to ralated game8.co page
link = 'https://game8.co/games/God-of-War-Ragnarok/archives/395838'
game8List = pd.read_html(link, extract_links='all')

# Create dis=ctionary with all attachments
perkLinkDict = {'Axe': pd.Series(dict(game8List[1]['Attachment', None].tolist())), 
                'Blades': pd.Series(dict(game8List[2]['Attachment', None].tolist())), 
                'Spear': pd.Series(dict(game8List[4]['Attachment', None].tolist())), 
                'Shield': pd.Series(dict(game8List[3]['Attachment', None].tolist()))}

perkLinkDict
# Out:
# {'Axe': Banahogg Knob                   https://game8.co/games/God-of-War-Ragnarok/arc...
#  Fortified Frost Knob            https://game8.co/games/God-of-War-Ragnarok/arc...
#  Grip of Healing Harmony         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Grip of Radiant Reflection      https://game8.co/games/God-of-War-Ragnarok/arc...
#  Grip of the Fallen Alchemist    https://game8.co/games/God-of-War-Ragnarok/arc...
#  Grip of the Nine Realms         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Grip of Weighted Recovery       https://game8.co/games/God-of-War-Ragnarok/arc...
#  Haur's Lucky Knob               https://game8.co/games/God-of-War-Ragnarok/arc...
#  Runic Hailstone Knob            https://game8.co/games/God-of-War-Ragnarok/arc...
#  Stonecutter's Knob              https://game8.co/games/God-of-War-Ragnarok/arc...
#  The Furious Maul                https://game8.co/games/God-of-War-Ragnarok/arc...
#  Wooden Knob                     https://game8.co/games/God-of-War-Ragnarok/arc...
#  dtype: object,
#  'Blades': Cursed Empress Handles          https://game8.co/games/God-of-War-Ragnarok/arc...
#  Deadly Obsidian Handles         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Hardened War Handles            https://game8.co/games/God-of-War-Ragnarok/arc...
#  Luminous Recovery Handles       https://game8.co/games/God-of-War-Ragnarok/arc...
#  Pommels of Agile Deceit         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Pommels of Brutal Might         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Pommels of Burning Unity        https://game8.co/games/God-of-War-Ragnarok/arc...
#  Pommels of the Nine Realms      https://game8.co/games/God-of-War-Ragnarok/arc...
#  Pommels of the True Flame       https://game8.co/games/God-of-War-Ragnarok/arc...
#  Pommels of the Undying Spark    https://game8.co/games/God-of-War-Ragnarok/arc...
#  Radiant Warden Handles          https://game8.co/games/God-of-War-Ragnarok/arc...
#  Steel Handles                   https://game8.co/games/God-of-War-Ragnarok/arc...
#  dtype: object,
#  'Spear': Hind of Deadly Vitality        https://game8.co/games/God-of-War-Ragnarok/arc...
#  Hind of Volatile Might         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Hind of Weightless Recovery    https://game8.co/games/God-of-War-Ragnarok/arc...
#  Battle-Scarred Sauroter        https://game8.co/games/God-of-War-Ragnarok/arc...
#  Warrior's Echo Sauroter        https://game8.co/games/God-of-War-Ragnarok/arc...
#  Hind of the Nine Realms        https://game8.co/games/God-of-War-Ragnarok/arc...
#  Hind of Attuned Elements       https://game8.co/games/God-of-War-Ragnarok/arc...
#  Mighty Olympic Sauroter        https://game8.co/games/God-of-War-Ragnarok/arc...
#  Charging Assault Sauroter      https://game8.co/games/God-of-War-Ragnarok/arc...
#  Lion's Roar Sauroter           https://game8.co/games/God-of-War-Ragnarok/arc...
#  Hind of the Four Winds         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Soldier's Sauroter             https://game8.co/games/God-of-War-Ragnarok/arc...
#  dtype: object,
#  'Shield': Rond of Absorption         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of Affliction         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of Aggravation        https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of Deflection         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of Disruption         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of Expedition         https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of Fortification      https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of Obliteration       https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of Purification       https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of Restoration        https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of the Nine Realms    https://game8.co/games/God-of-War-Ragnarok/arc...
#  Rond of Volition           https://game8.co/games/God-of-War-Ragnarok/arc...
#  dtype: object}

# %%
# Fetch attachments from wiki and perks from game8.co
dfAttach = pd.DataFrame()

for weapon in weapons:
    series = linkDict[weapon]

    for itemName, url in series.items():
        tables = pd.read_html(url)[1:3]
        print(itemName)
    
        newTable = pd.DataFrame()
    
        for j in tables:
            fetchedTable = getItemFeatures(j, dfAttach)
            newTable = pd.concat([newTable, fetchedTable], ignore_index=True, axis=0)
    
        try:
            perkLink = perkLinkDict[weapon][unidecode(itemName)]
        except Exception as error:
            print("An exception occurred:", error)
            perk = 'Unable to fetch'
        else:
            perk = pd.read_html(perkLink)[0].iat[-1, 0]
    
        newTable[['Type', 'Item', 'Perk', 'Wiki Link']] = weapon, itemName, perk, url
        dfAttach = pd.concat([dfAttach, newTable], ignore_index=True, axis=0)
# Out:
# Wooden Knob
# The Furious Maul
# Grip of Darkdale
# An exception occurred: 'Grip of Darkdale'
# Fortified Frost Knob
# Haur's Lucky Knob
# Grip of Weighted Recovery
# Stonecutter's Knob
# Grip of Healing Harmony
# Grip of the Fallen Alchemist
# Grip of Radiant Reflection
# Banahogg Knob
# Runic Hailstone Knob
# Grip of the Nine Realms
# Steel Handles
# Deadly Obsidian Handles
# Darkdale Handles
# An exception occurred: 'Darkdale Handles'
# Cursed Empress Handles
# Pommels of the Undying Spark
# Radiant Warden Handles
# Pommels of Agile Deceit
# Pommels of Brutal Might
# Hardened War Handles
# Pommels of the True Flame
# Pommels of the Nine Realms
# Pommels of Burning Unity
# Luminous Recovery Handles
# Soldier's Sauroter
# Lion's Roar Sauroter
# Charging Assault Sauroter
# Mighty Olympic Sauroter
# Hind of Attuned Elements
# Battle-Scarred Sauroter
# Hind of Weightless Recovery
# Hind of Volatile Might
# Hind of the Nine Realms
# Hind of the Four Winds
# Warrior's Echo Sauroter
# Hind of Deadly Vitality
# Rönd of Volition
# Rönd of Aggravation
# Rönd of Expedition
# Rönd of Affliction
# Rönd of Restoration
# Rönd of Deflection
# Rönd of Purification
# Rönd of the Nine Realms
# Rönd of Fortification
# Rönd of Absorption
# Rönd of Disruption
# Rönd of Obliteration

# %%
# Adding the missing "Darkdale" attachments 
darkdaleGripPerk = 'DEADLY AWAKENING Killing enemies with a Frost Awaken (Hold Triangle) attack causes a Frost shockwave and re-Frost Awakens the Axe.'
darkdaleHandlesPerk = 'DEADLY FLAMES Killing enemies with a Flame Whiplash (Mash Triangle) attack causes a Burn shockwave and increases Burn status inflicted for a duration.'
dfAttach.loc[dfAttach['Item'] == 'Darkdale Handles', 'Perk'] = darkdaleHandlesPerk
dfAttach.loc[dfAttach['Item'] == 'Grip of Darkdale', 'Perk'] = darkdaleGripPerk

# %%
# Rearrange the dataframe with attachments
dfAttach = dfAttach[['Item', 'Type', 'Lvl','STR', 'DEF', 'RNC', 'VIT', 'CLD', 'LCK', 'Acquisition/Costs', 'Wiki Link', 'Perk']]
dfAttach = dfAttach.astype({'STR': 'float', 'DEF': 'float', 'RNC': 'float', 'VIT': 'float', 'CLD': 'float', 'LCK': 'float'})
dfAttach.dtypes
# Out:
# Item                  object
# Type                  object
# Lvl                   object
# STR                  float64
# DEF                  float64
# RNC                  float64
# VIT                  float64
# CLD                  float64
# LCK                  float64
# Acquisition/Costs     object
# Wiki Link             object
# Perk                  object
# dtype: object

# %%
dfAttach
# Out:
#                      Item    Type  Lvl   STR   DEF   RNC   VIT   CLD   LCK  \
# 0             Wooden Knob     Axe    1   NaN   NaN   NaN   NaN   NaN   NaN
# 1             Wooden Knob     Axe    2   4.0   NaN   NaN   NaN   NaN   NaN
# 2             Wooden Knob     Axe    3   8.0   NaN   NaN   NaN   NaN   NaN
# 3             Wooden Knob     Axe    4  11.0   NaN   NaN   NaN   NaN   NaN
# 4             Wooden Knob     Axe    5  15.0   NaN   NaN   NaN   NaN   NaN
# ..                    ...     ...  ...   ...   ...   ...   ...   ...   ...
# 476  Rönd of Obliteration  Shield    9  11.0  11.0  14.0  14.0  14.0  14.0
# 477  Rönd of Obliteration  Shield  9.1  13.0  13.0  16.0  16.0  16.0  16.0
# 478  Rönd of Obliteration  Shield  9.2  14.0  14.0  18.0  18.0  18.0  18.0
# 479  Rönd of Obliteration  Shield  9.3  16.0  16.0  20.0  20.0  20.0  20.0
# 480  Rönd of Obliteration  Shield   10  17.0  17.0  21.0  21.0  21.0  21.0
#
#                                      Acquisition/Costs  \
# 0                                      Start the game.
# 1                Upgrade: - 400 Hacksilver - 3 Rawhide
# 2                Upgrade: - 800 Hacksilver - 6 Rawhide
# 3             Upgrade: - 2400 Hacksilver - 2 Stonewood
# 4             Upgrade: - 4000 Hacksilver - 5 Stonewood
# ..                                                 ...
# 476  Upgrade: 14,000 Hacksilver - 30 Dust of Realms...
# 477          Craft: - 15,000 Hacksilver - 10 Skap Slag
# 478  Upgrade: - 16,000 Hacksilver - 20 Skap Slag - ...
# 479  Upgrade: - 18,000 Hacksilver - 30 Skap Slag - ...
# 480  Upgrade: - 20,000 Hacksilver - 40 Skap Slag - ...
#
#                                              Wiki Link  \
# 0         https://godofwar.fandom.com/wiki/Wooden_Knob
# 1         https://godofwar.fandom.com/wiki/Wooden_Knob
# 2         https://godofwar.fandom.com/wiki/Wooden_Knob
# 3         https://godofwar.fandom.com/wiki/Wooden_Knob
# 4         https://godofwar.fandom.com/wiki/Wooden_Knob
# ..                                                 ...
# 476  https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
# 477  https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
# 478  https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
# 479  https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
# 480  https://godofwar.fandom.com/wiki/R%C3%B6nd_of_...
#
#                                                   Perk
# 0             This attachment does not grant any perk.
# 1             This attachment does not grant any perk.
# 2             This attachment does not grant any perk.
# 3             This attachment does not grant any perk.
# 4             This attachment does not grant any perk.
# ..                                                 ...
# 476  SHARDS OF THE VALKYRIE Hold Block for several ...
# 477  SHARDS OF THE VALKYRIE Hold Block for several ...
# 478  SHARDS OF THE VALKYRIE Hold Block for several ...
# 479  SHARDS OF THE VALKYRIE Hold Block for several ...
# 480  SHARDS OF THE VALKYRIE Hold Block for several ...
#
# [481 rows x 12 columns]

# %% [markdown]
# ## Fetching enchantments from godofwar.fandom.com

# %%
# Fetch enthantments table from wiki
url = 'https://godofwar.fandom.com/wiki/Enchantments_(Ragnar%C3%B6k)?so=search'
tables = pd.read_html(url)
# Create dataframe with enchantments
dfEnch = pd.DataFrame()

# %%
# Add the "realm" class enchantments to dataframe
for i in tables[0:9]:
    table = i.copy()
    enchSet = table.columns[0][0].split(' ')[0]
    table.columns = table.columns.droplevel()
    setPerk = 'When wearing 3: ' + table.iloc[-2, 1]

    correctRows = range(0, table.shape[0]-2, 2)
    
    for i in correctRows:
        stats = table.at[i+1, 'Enchantment Name'].split(' ')
        for j in range(1, len(stats), 2):
            table.at[i, stats[j]] = stats[j-1]
    
    table = table.iloc[correctRows]
    table[['Set', 'Perk', 'Stat Requirement']] = enchSet, setPerk, '-'
    table.rename(columns={'Enchantment Name': 'Item'}, inplace=True)

    dfEnch = pd.concat([dfEnch, table], ignore_index=True, axis=0)

dfEnch
# Out:
#                         Item  \
# 0        Midgard's Endurance
# 1           Midgard's Honour
# 2           Midgard's Virtue
# 3          Midgard's Justice
# 4          Midgard's Bravery
# 5         Asgard's Fortitude
# 6             Asgard's Might
# 7          Asgard's Security
# 8           Asgard's Justice
# 9            Asgard's Virtue
# 10        Vanaheim's Fortune
# 11         Vanaheim's Honour
# 12         Vanaheim's Virtue
# 13          Vanaheim's Power
# 14      Vanaheim's Fortitude
# 15     Svartalfheim's Honour
# 16     Svartalfheim's Safety
# 17    Svartalfheim's Fortune
# 18  Svartalfheim's Lifeblood
# 19  Svartalfheim's Fortitude
# 20        Muspelheim's Force
# 21    Muspelheim's Endurance
# 22      Muspelheim's Essence
# 23     Muspelheim's Blessing
# 24   Muspelheim's Protection
# 25       Niflheim's Security
# 26        Niflheim's Fortune
# 27          Niflheim's Force
# 28         Niflheim's Virtue
# 29        Niflheim's Justice
# 30          Alfheim's Vigour
# 31          Alfheim's Honour
# 32         Alfheim's Fortune
# 33          Alfheim's Virtue
# 34         Alfheim's Justice
# 35         Helheim's Essence
# 36          Helheim's Honour
# 37           Helheim's Might
# 38           Helheim's Force
# 39          Helheim's Virtue
# 40       Jötunheim's Essence
# 41        Jötunheim's Honour
# 42     Jötunheim's Endurance
# 43        Jötunheim's Virtue
# 44         Jötunheim's Force
#
#                                           Acquisition  CLD  LCK  VIT  RNC  \
# 0                                      Defeat Níðhögg   10  NaN  NaN  NaN
# 1   Craft: - 1000 Hacksilver - Commence your searc...    5    8  NaN  NaN
# 2   Craft: - 1500 Hacksilver - Return to Sindri's ...    4  NaN    9  NaN
# 3                        Treasure Hunt: Viking's Gift    3  NaN  NaN   12
# 4              Nornir Chest: 31st Nornir Chest opened    2  NaN  NaN  NaN
# 5                   Berserker: Harðrefill the Callous    3  NaN  NaN  NaN
# 6                       Berserker: Beigaðr the Feared    3  NaN  NaN  NaN
# 7   Berserkers: Svipdagr the Cold & The Sisters of...    3  NaN  NaN   12
# 8                       Treasure Hunt: A Scar is Born    3   12  NaN  NaN
# 9             Shop Coffin: Return the moon to the sky    3  NaN    3  NaN
# 10          Craft: - 1000 Hacksilver - Defeat Níðhögg  NaN   10  NaN  NaN
# 11  Craft: - 1000 Hacksilver - Commence your searc...  NaN    5  NaN    8
# 12  Craft: - 1500 Hacksilver - Return to Sindri's ...  NaN    4  NaN  NaN
# 13                    Treasure Hunt: The Giant's Toes  NaN    3  NaN  NaN
# 14  Drop: The Crimson Dread - Fought during the Fa...   20    2  NaN  NaN
# 15                    Favour: Conscience for the Dead  NaN  NaN  NaN  NaN
# 16                        Favour: Garden for the Dead  NaN  NaN  NaN  NaN
# 17                          Favour: Cure for the Dead    9  NaN  NaN  NaN
# 18                  Treasure Hunt: Fruits of Industry  NaN  NaN   12  NaN
# 19             Nornir Chest: 32nd Nornir Chest opened  NaN   20  NaN  NaN
# 20      Muspelheim Crucible: Shield Breaker Challenge  NaN  NaN  NaN    3
# 21           Muspelheim Crucible: Boss Rush Challenge  NaN  NaN  NaN    3
# 22           Muspelheim Crucible: Onslaught Challenge  NaN   12  NaN    3
# 23                        Treasure Hunt: Mining Glory  NaN  NaN   12    3
# 24  Shop Coffin: - Open after completing the realm...   10    7  NaN    3
# 25     Craft: - 1000 Hacksilver - Break Freya's Curse  NaN  NaN  NaN  NaN
# 26  Craft: - 1500 Hacksilver - Return to Sindri's ...  NaN  NaN    8  NaN
# 27             Craft: - 2500 Hacksilver - Defeat Garm  NaN    9  NaN  NaN
# 28                   Treasure Hunt: Under the Rainbow   12  NaN  NaN  NaN
# 29  Favor: The Eyes of Odin - Defeat the Raven Keeper  NaN  NaN  NaN  NaN
# 30  Favor: Freyr's Gift - Found in a blue sand cir...  NaN  NaN  NaN  NaN
# 31  Drop: Frost Phantom - Fought in The Forbidden ...    8  NaN  NaN  NaN
# 32  Drop: Gravel Belly - Fought during the Favour ...  NaN  NaN  NaN    9
# 33                     Treasure Hunt: Forgotten Tower  NaN   12  NaN  NaN
# 34             Nornir Chest: 33rd Nornir Chest opened  NaN  NaN   20  NaN
# 35  Craft: - 1000 Hacksilver - Commence Search for...  NaN  NaN   10  NaN
# 36  Craft: - 1500 Hacksilver - Return to Sindri's ...    8  NaN    5  NaN
# 37             Craft: - 2500 Hacksilver - Defeat Garm  NaN  NaN    4  NaN
# 38                   Treasure Hunt: Demise of Dagestr  NaN  NaN    3  NaN
# 39                  Defeat Berserker King Hrólf Kraki  NaN  NaN    2   20
# 40  Favour: Guiding Light - Buried near the broken...  NaN    6    4  NaN
# 41        Drop: Vísi Haglkorn - Lake of Nine, Midgard  NaN    6    4  NaN
# 42        Drop: Flame Phantom - Lake of Nine, Midgard  NaN  NaN    3   12
# 43                       Treasure Hunt: Washed Ashore   12  NaN    3  NaN
# 44  Drop: The Everlasting - Found at Dragon Beach,...    6    6    6    6
#
#     DEF           Set                                               Perk  \
# 0   NaN       Midgard  When wearing 3: Increases the damage of all of...
# 1   NaN       Midgard  When wearing 3: Increases the damage of all of...
# 2   NaN       Midgard  When wearing 3: Increases the damage of all of...
# 3   NaN       Midgard  When wearing 3: Increases the damage of all of...
# 4    20       Midgard  When wearing 3: Increases the damage of all of...
# 5   NaN        Asgard  When wearing 3: Increases the damage of all of...
# 6    12        Asgard  When wearing 3: Increases the damage of all of...
# 7   NaN        Asgard  When wearing 3: Increases the damage of all of...
# 8   NaN        Asgard  When wearing 3: Increases the damage of all of...
# 9     7        Asgard  When wearing 3: Increases the damage of all of...
# 10  NaN      Vanaheim  When wearing 3: Increases Kratos' Melee damage...
# 11  NaN      Vanaheim  When wearing 3: Increases Kratos' Melee damage...
# 12  NaN      Vanaheim  When wearing 3: Increases Kratos' Melee damage...
# 13   12      Vanaheim  When wearing 3: Increases Kratos' Melee damage...
# 14  NaN      Vanaheim  When wearing 3: Increases Kratos' Melee damage...
# 15   10  Svartalfheim  When wearing 3: Increases Stun damage inflicte...
# 16    5  Svartalfheim  When wearing 3: Increases Stun damage inflicte...
# 17    4  Svartalfheim  When wearing 3: Increases Stun damage inflicte...
# 18    3  Svartalfheim  When wearing 3: Increases Stun damage inflicte...
# 19    2  Svartalfheim  When wearing 3: Increases Stun damage inflicte...
# 20  NaN    Muspelheim  When wearing 3: Increases Kratos' Melee damage...
# 21   12    Muspelheim  When wearing 3: Increases Kratos' Melee damage...
# 22  NaN    Muspelheim  When wearing 3: Increases Kratos' Melee damage...
# 23  NaN    Muspelheim  When wearing 3: Increases Kratos' Melee damage...
# 24  NaN    Muspelheim  When wearing 3: Increases Kratos' Melee damage...
# 25   10      Niflheim  When wearing 3: Increases Kratos' Melee damage...
# 26    5      Niflheim  When wearing 3: Increases Kratos' Melee damage...
# 27    4      Niflheim  When wearing 3: Increases Kratos' Melee damage...
# 28    3      Niflheim  When wearing 3: Increases Kratos' Melee damage...
# 29    2      Niflheim  When wearing 3: Increases Kratos' Melee damage...
# 30  NaN       Alfheim  When wearing 3: Last-second dodges empower Kra...
# 31  NaN       Alfheim  When wearing 3: Last-second dodges empower Kra...
# 32  NaN       Alfheim  When wearing 3: Last-second dodges empower Kra...
# 33  NaN       Alfheim  When wearing 3: Last-second dodges empower Kra...
# 34  NaN       Alfheim  When wearing 3: Last-second dodges empower Kra...
# 35  NaN       Helheim  When wearing 3: Increases Kratos' Melee damage...
# 36  NaN       Helheim  When wearing 3: Increases Kratos' Melee damage...
# 37    9       Helheim  When wearing 3: Increases Kratos' Melee damage...
# 38  NaN       Helheim  When wearing 3: Increases Kratos' Melee damage...
# 39  NaN       Helheim  When wearing 3: Increases Kratos' Melee damage...
# 40  NaN     Jötunheim  When wearing 3: Increases Kratos' Maximum Rage...
# 41    4     Jötunheim  When wearing 3: Increases Kratos' Maximum Rage...
# 42  NaN     Jötunheim  When wearing 3: Increases Kratos' Maximum Rage...
# 43  NaN     Jötunheim  When wearing 3: Increases Kratos' Maximum Rage...
# 44    6     Jötunheim  When wearing 3: Increases Kratos' Maximum Rage...
#
#    Stat Requirement  STR
# 0                 -  NaN
# 1                 -  NaN
# 2                 -  NaN
# 3                 -  NaN
# 4                 -  NaN
# 5                 -   12
# 6                 -  NaN
# 7                 -  NaN
# 8                 -  NaN
# 9                 -    7
# 10                -  NaN
# 11                -  NaN
# 12                -    9
# 13                -  NaN
# 14                -  NaN
# 15                -  NaN
# 16                -    8
# 17                -  NaN
# 18                -  NaN
# 19                -  NaN
# 20                -   12
# 21                -  NaN
# 22                -  NaN
# 23                -  NaN
# 24                -  NaN
# 25                -  NaN
# 26                -  NaN
# 27                -  NaN
# 28                -  NaN
# 29                -   20
# 30                -   10
# 31                -    5
# 32                -    4
# 33                -    3
# 34                -    2
# 35                -  NaN
# 36                -  NaN
# 37                -  NaN
# 38                -   12
# 39                -  NaN
# 40                -    4
# 41                -  NaN
# 42                -  NaN
# 43                -  NaN
# 44                -    6

# %%
# Separate the "burden" class enchantments, as their table format differs from the rest
burdensList = tables.pop(52)
burdensList
# Out:
#                   Burdens
#          Enchantment Name                                               Perk
# 0          Burden of Stun                                     Disrupted Stun
# 1          Burden of Stun                               Reduces Stun damage.
# 2         Burden of Runic                                    Disrupted Runic
# 3         Burden of Runic                       Reduces Runic Attack damage.
# 4      Burden of Momentum                                 Disrupted Momentum
# 5      Burden of Momentum  Weapon damage is reduced unless the Permafrost...
# 6      Burden of Elements                                 Disrupted Elements
# 7      Burden of Elements  Decreases Resistance to all Status Effects. De...
# 8   Burden of Restoration                              Disrupted Restoration
# 9   Burden of Restoration  Decreases the healing from Healthstones, Rage,...
# 10     Burden of Weaponry                                 Disrupted Weaponry
# 11     Burden of Weaponry  Reduces the damage and stagger potential of al...
# 12         Burden of Rage                                     Disrupted Rage
# 13         Burden of Rage        Decreases the rate at which Rage is gained.
# 14        Burden of Guard                                    Disrupted Guard
# 15        Burden of Guard  Kratos now takes damage and loses Rage when Bl...
# 16      Burden of Evasion                                  Disrupted Evasion
# 17      Burden of Evasion  Dodge Rolling (Double Tap X) inflicts the Fros...
# 18            Acquisition  Craft: - 10,000 Hacksilver each - Visit Sindri...
# 19            Description  "Enchantments for the Spartan wishing to chall...

# %%
# Complement dataframe with the rest of enchantments
for i in tables[9:61]:
    table = i.copy()
    item = table.columns[0]
    table.set_index(item, inplace=True)
    acquisition = table.loc['Acquisition'].iat[0]
    
    statsDict = {}
    if 'Stats' in table.index:
        stats = table.loc['Stats'].iat[0].split(' ')
        for j in range(1, len(stats), 2):
            statsDict[stats[j]] = stats[j-1]

    if 'Perk' in table.index:
        perk = table.loc['Perk'].iat[0,0] + ': ' + table.loc['Perk'].iat[1,0]
    else:
        perk = '-'

    if 'Stat Requirement' in table.index:
        requirements = table.loc['Stat Requirement'].iat[0]
    else:
        requirements = '-'

    dfDict = {'Item': item, 'Perk': perk, 'Acquisition': acquisition, 'Stat Requirement': requirements, 'Set': '-'}
    dfDict.update(statsDict)

    dfEnch = pd.concat([dfEnch, pd.DataFrame([dfDict])], ignore_index=True, axis=0)

dfEnch
# Out:
#                    Item                                        Acquisition  \
# 0   Midgard's Endurance                                     Defeat Níðhögg
# 1      Midgard's Honour  Craft: - 1000 Hacksilver - Commence your searc...
# 2      Midgard's Virtue  Craft: - 1500 Hacksilver - Return to Sindri's ...
# 3     Midgard's Justice                       Treasure Hunt: Viking's Gift
# 4     Midgard's Bravery             Nornir Chest: 31st Nornir Chest opened
# ..                  ...                                                ...
# 92             Lífdagar                      Berserker: Hvítserkr the Bold
# 93                Garpr                    Berserker: Haklangr the Bearded
# 94              Mannvit  Berserker: Svipdagr the Cold and the Sisters o...
# 95                 Vald                       Berserker: Hjalti the Stolid
# 96              Heppinn                 Berserker: Skjóthendi the Unerring
#
#     CLD  LCK  VIT  RNC  DEF      Set  \
# 0    10  NaN  NaN  NaN  NaN  Midgard
# 1     5    8  NaN  NaN  NaN  Midgard
# 2     4  NaN    9  NaN  NaN  Midgard
# 3     3  NaN  NaN   12  NaN  Midgard
# 4     2  NaN  NaN  NaN   20  Midgard
# ..  ...  ...  ...  ...  ...      ...
# 92  NaN  NaN   30  NaN    5        -
# 93  NaN   20  NaN  NaN  NaN        -
# 94   20  NaN  NaN   20  NaN        -
# 95   30  NaN  NaN  NaN  NaN        -
# 96  NaN   30  NaN    5  NaN        -
#
#                                                  Perk Stat Requirement  STR
# 0   When wearing 3: Increases the damage of all of...                -  NaN
# 1   When wearing 3: Increases the damage of all of...                -  NaN
# 2   When wearing 3: Increases the damage of all of...                -  NaN
# 3   When wearing 3: Increases the damage of all of...                -  NaN
# 4   When wearing 3: Increases the damage of all of...                -  NaN
# ..                                                ...              ...  ...
# 92                                                  -                -  NaN
# 93                                                  -                -   20
# 94                                                  -                -  NaN
# 95                                                  -                -    5
# 96                                                  -                -  NaN
#
# [97 rows x 11 columns]

# %%
# Complement dataframe with the "burden" class enchantments
burdens = burdensList.copy()
burdens.columns = burdens.columns.droplevel()
burdens.rename(columns={'Enchantment Name': 'Item'}, inplace=True)

acquisition = "Craft: - 10,000 Hacksilver - Visit Sindri's House for the first time."
correctRows = range(0, burdens.shape[0]-2, 2)

for i in correctRows:
    burdens.at[i, 'Perk'] = burdens.at[i, 'Perk'] + ': ' + burdens.at[i+1, 'Perk']

burdens = burdens.iloc[correctRows]
burdens[['Acquisition', 'Set', 'Stat Requirement']] = acquisition, '-', '-'

dfEnch = pd.concat([dfEnch, burdens], ignore_index=True, axis=0)

dfEnch
# Out:
#                       Item                                        Acquisition  \
# 0      Midgard's Endurance                                     Defeat Níðhögg
# 1         Midgard's Honour  Craft: - 1000 Hacksilver - Commence your searc...
# 2         Midgard's Virtue  Craft: - 1500 Hacksilver - Return to Sindri's ...
# 3        Midgard's Justice                       Treasure Hunt: Viking's Gift
# 4        Midgard's Bravery             Nornir Chest: 31st Nornir Chest opened
# ..                     ...                                                ...
# 101  Burden of Restoration  Craft: - 10,000 Hacksilver - Visit Sindri's Ho...
# 102     Burden of Weaponry  Craft: - 10,000 Hacksilver - Visit Sindri's Ho...
# 103         Burden of Rage  Craft: - 10,000 Hacksilver - Visit Sindri's Ho...
# 104        Burden of Guard  Craft: - 10,000 Hacksilver - Visit Sindri's Ho...
# 105      Burden of Evasion  Craft: - 10,000 Hacksilver - Visit Sindri's Ho...
#
#      CLD  LCK  VIT  RNC  DEF      Set  \
# 0     10  NaN  NaN  NaN  NaN  Midgard
# 1      5    8  NaN  NaN  NaN  Midgard
# 2      4  NaN    9  NaN  NaN  Midgard
# 3      3  NaN  NaN   12  NaN  Midgard
# 4      2  NaN  NaN  NaN   20  Midgard
# ..   ...  ...  ...  ...  ...      ...
# 101  NaN  NaN  NaN  NaN  NaN        -
# 102  NaN  NaN  NaN  NaN  NaN        -
# 103  NaN  NaN  NaN  NaN  NaN        -
# 104  NaN  NaN  NaN  NaN  NaN        -
# 105  NaN  NaN  NaN  NaN  NaN        -
#
#                                                   Perk Stat Requirement  STR
# 0    When wearing 3: Increases the damage of all of...                -  NaN
# 1    When wearing 3: Increases the damage of all of...                -  NaN
# 2    When wearing 3: Increases the damage of all of...                -  NaN
# 3    When wearing 3: Increases the damage of all of...                -  NaN
# 4    When wearing 3: Increases the damage of all of...                -  NaN
# ..                                                 ...              ...  ...
# 101  Disrupted Restoration: Decreases the healing f...                -  NaN
# 102  Disrupted Weaponry: Reduces the damage and sta...                -  NaN
# 103  Disrupted Rage: Decreases the rate at which Ra...                -  NaN
# 104  Disrupted Guard: Kratos now takes damage and l...                -  NaN
# 105  Disrupted Evasion: Dodge Rolling (Double Tap X...                -  NaN
#
# [106 rows x 11 columns]

# %%
dfEnch = dfEnch[['Item', 'Set', 'STR', 'DEF', 'RNC', 'VIT', 'CLD', 'LCK', 'Acquisition', 'Stat Requirement', 'Perk']]
dfEnch = dfEnch.astype({'STR': 'float', 'DEF': 'float', 'RNC': 'float', 'VIT': 'float', 'CLD': 'float', 'LCK': 'float'})
dfEnch.dtypes
dfEnch
# Out:
#                       Item      Set  STR   DEF   RNC  VIT   CLD  LCK  \
# 0      Midgard's Endurance  Midgard  NaN   NaN   NaN  NaN  10.0  NaN
# 1         Midgard's Honour  Midgard  NaN   NaN   NaN  NaN   5.0  8.0
# 2         Midgard's Virtue  Midgard  NaN   NaN   NaN  9.0   4.0  NaN
# 3        Midgard's Justice  Midgard  NaN   NaN  12.0  NaN   3.0  NaN
# 4        Midgard's Bravery  Midgard  NaN  20.0   NaN  NaN   2.0  NaN
# ..                     ...      ...  ...   ...   ...  ...   ...  ...
# 101  Burden of Restoration        -  NaN   NaN   NaN  NaN   NaN  NaN
# 102     Burden of Weaponry        -  NaN   NaN   NaN  NaN   NaN  NaN
# 103         Burden of Rage        -  NaN   NaN   NaN  NaN   NaN  NaN
# 104        Burden of Guard        -  NaN   NaN   NaN  NaN   NaN  NaN
# 105      Burden of Evasion        -  NaN   NaN   NaN  NaN   NaN  NaN
#
#                                            Acquisition Stat Requirement  \
# 0                                       Defeat Níðhögg                -
# 1    Craft: - 1000 Hacksilver - Commence your searc...                -
# 2    Craft: - 1500 Hacksilver - Return to Sindri's ...                -
# 3                         Treasure Hunt: Viking's Gift                -
# 4               Nornir Chest: 31st Nornir Chest opened                -
# ..                                                 ...              ...
# 101  Craft: - 10,000 Hacksilver - Visit Sindri's Ho...                -
# 102  Craft: - 10,000 Hacksilver - Visit Sindri's Ho...                -
# 103  Craft: - 10,000 Hacksilver - Visit Sindri's Ho...                -
# 104  Craft: - 10,000 Hacksilver - Visit Sindri's Ho...                -
# 105  Craft: - 10,000 Hacksilver - Visit Sindri's Ho...                -
#
#                                                   Perk
# 0    When wearing 3: Increases the damage of all of...
# 1    When wearing 3: Increases the damage of all of...
# 2    When wearing 3: Increases the damage of all of...
# 3    When wearing 3: Increases the damage of all of...
# 4    When wearing 3: Increases the damage of all of...
# ..                                                 ...
# 101  Disrupted Restoration: Decreases the healing f...
# 102  Disrupted Weaponry: Reduces the damage and sta...
# 103  Disrupted Rage: Decreases the rate at which Ra...
# 104  Disrupted Guard: Kratos now takes damage and l...
# 105  Disrupted Evasion: Dodge Rolling (Double Tap X...
#
# [106 rows x 11 columns]

# %% [markdown]
# ## Fetching shields from godofwar.fandom.com

# %%
# Shield links
shieldsUrls = ['https://godofwar.fandom.com/wiki/Guardian_Shield',
               'https://godofwar.fandom.com/wiki/Dauntless_Shield',
               'https://godofwar.fandom.com/wiki/Stone_Wall_Shield',
               'https://godofwar.fandom.com/wiki/Shatter_Star_Shield',
               'https://godofwar.fandom.com/wiki/Onslaught_Shield',
               'https://godofwar.fandom.com/wiki/Spartan_Aspis']

# %%
# Fetch shields properties from wiki
def getShieldLevel(col):
    list = col.replace(':', '').split(' ')
    if '•' in list[-1]:
        return list[1] + '.' + str(list[-1].count('•'))
    else: return list[1]

def fetchShield(table, url, df):
    table = table.copy()
    title = table.columns[0][0]
    itemName = title.replace(' +', '')
    table.columns = table.columns.droplevel()
    table.rename(columns={'Stats': 'Lvl'}, inplace=True)

    if 'Acquisition' in table.columns:
        table.rename(columns={'Acquisition': 'Acquisition/Costs'}, inplace=True)

    lastRow = table.loc[table['Lvl']=='Shield Strike'].index[0]
    correctRows = range(0, lastRow, 2)

    perk = table.loc[table['Lvl']=='Shield Strike'].iat[0,1] + ': ' + table.loc[table['Lvl']=='Shield Strike'].iat[1,1]
    table = table[:-2]
    
    for i in correctRows:
        stats = table.at[i+1, 'Lvl'].split(' ')
        for j in range(1, len(stats), 2):
            table.at[i, stats[j]] = stats[j-1]
    
    table = table.iloc[correctRows]
        
    table['Lvl'] = table['Lvl'].apply(getLevel)
    table[['Perk', 'Item', 'Wiki Link']] = perk, itemName, url

    df = pd.concat([df, table], ignore_index=True, axis=0)
    
    return df

# %%
# Create dataframe with shields
dfShields = pd.DataFrame()

for url in shieldsUrls:
    itemName = url.split('/')[-1].replace('_', ' ')
    tables = pd.read_html(url)

    print(itemName)

    for i in tables:
        if type(i.columns[0])==tuple and len(i.columns[0])==2:
            if itemName in i.columns[0][0]:
                dfShields = fetchShield(i, url, dfShields)
# Out:
# Guardian Shield
# Dauntless Shield
# Stone Wall Shield
# Shatter Star Shield
# Onslaught Shield
# Spartan Aspis

# %%
dfShields['STR'] = np.nan
dfShields = dfShields[['Item', 'Lvl', 'STR', 'DEF', 'RNC', 'VIT', 'CLD', 'LCK', 'Acquisition/Costs', 'Wiki Link', 'Perk']]
dfShields.astype({'STR': 'float', 'DEF': 'float', 'RNC': 'float', 'VIT': 'float', 'CLD': 'float', 'LCK': 'float'})

dfShields
# Out:
#                Item  Lvl  STR  DEF  RNC  VIT  CLD  LCK  \
# 0   Guardian Shield    4  NaN   55  NaN  NaN  NaN  NaN
# 1   Guardian Shield    5  NaN   70  NaN  NaN  NaN  NaN
# 2   Guardian Shield    6  NaN   85  NaN  NaN  NaN  NaN
# 3   Guardian Shield    7  NaN  100  NaN  NaN  NaN  NaN
# 4   Guardian Shield    8  NaN  115  NaN  NaN  NaN  NaN
# ..              ...  ...  ...  ...  ...  ...  ...  ...
# 58    Spartan Aspis    9  NaN  130  NaN  NaN  NaN  NaN
# 59    Spartan Aspis  9.1  NaN  145  NaN  NaN  NaN  NaN
# 60    Spartan Aspis  9.2  NaN  160  NaN  NaN  NaN  NaN
# 61    Spartan Aspis  9.3  NaN  175  NaN  NaN  NaN  NaN
# 62    Spartan Aspis   10  NaN  190  NaN  NaN  NaN  NaN
#
#                                     Acquisition/Costs  \
# 0   Acquire from Sindri, before commencing your se...
# 1          Upgrade: - 5000 Hacksilver - 6 Honed Metal
# 2       Upgrade: - 7500 Hacksilver - 2 Luminous Alloy
# 3      Upgrade: - 11000 Hacksilver - 4 Luminous Alloy
# 4   Upgrade: - 15000 Hacksilver - 6 Luminous Alloy...
# ..                                                ...
# 58    Upgrade: - 20000 Hacksilver - 10 Luminous Alloy
# 59          Craft: - 21,000 Hacksilver - 10 Skap Slag
# 60  Upgrade: - 22,000 Hacksilver - 20 Skap Slag - ...
# 61  Upgrade: - 23,000 Hacksilver - 30 Skap Slag - ...
# 62  Upgrade: - 25,000 Hacksilver - 40 Skap Slag - ...
#
#                                            Wiki Link  \
# 0   https://godofwar.fandom.com/wiki/Guardian_Shield
# 1   https://godofwar.fandom.com/wiki/Guardian_Shield
# 2   https://godofwar.fandom.com/wiki/Guardian_Shield
# 3   https://godofwar.fandom.com/wiki/Guardian_Shield
# 4   https://godofwar.fandom.com/wiki/Guardian_Shield
# ..                                               ...
# 58    https://godofwar.fandom.com/wiki/Spartan_Aspis
# 59    https://godofwar.fandom.com/wiki/Spartan_Aspis
# 60    https://godofwar.fandom.com/wiki/Spartan_Aspis
# 61    https://godofwar.fandom.com/wiki/Spartan_Aspis
# 62    https://godofwar.fandom.com/wiki/Spartan_Aspis
#
#                                                  Perk
# 0   Shield Check: Double Tap L1 to quickly Shield ...
# 1   Shield Check: Double Tap L1 to quickly Shield ...
# 2   Shield Check: Double Tap L1 to quickly Shield ...
# 3   Shield Check: Double Tap L1 to quickly Shield ...
# 4   Shield Check: Double Tap L1 to quickly Shield ...
# ..                                                ...
# 58  Shield Check: Double Tap L1 to quickly Shield ...
# 59  Shield Check: Double Tap L1 to quickly Shield ...
# 60  Shield Check: Double Tap L1 to quickly Shield ...
# 61  Shield Check: Double Tap L1 to quickly Shield ...
# 62  Shield Check: Double Tap L1 to quickly Shield ...
#
# [63 rows x 11 columns]

# %% [markdown]
# ## Export dataframes to a .xlsx file

# %%
# Export dataframes to a .xls file
path = 'GoW_mastersheet.xlsx'

with pd.ExcelWriter(path, engine='xlsxwriter') as writer:
    dfArmor.to_excel(writer, sheet_name='Armor', index=False, freeze_panes=(1,1))
    dfAttach.to_excel(writer, sheet_name='Attachments', index=False, freeze_panes=(1,1))
    dfEnch.to_excel(writer, sheet_name='Enchantments', index=False, freeze_panes=(1,1))
    dfShields.to_excel(writer, sheet_name='Shields', index=False, freeze_panes=(1,1))
